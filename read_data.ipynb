# %%
import numpy as np
import pandas as pd

# %%
# !ls
# Out:
# data  read_data.ipynb  README.md

# %%
df = pd.read_csv('./data/train_5000.csv', sep=',')
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0     30669    Male   3.0             0              0           No
# 1     30468    Male  58.0             1              0          Yes
# 2     16523  Female   8.0             0              0           No
# 3     56543  Female  70.0             0              0          Yes
# 4     46136    Male  14.0             0              0           No
# ...     ...     ...   ...           ...            ...          ...
# 4994  41163  Female  26.0             0              0          Yes
# 4995   7165  Female  33.0             0              0          Yes
# 4996  10745  Female  52.0             0              0          Yes
# 4997  26015  Female  66.0             0              0          Yes
# 4998  58499  Female  31.0             0              0           No
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...
